# %%
import pandas as pd

# %%
df = pd.read_csv("dataset/titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       NaN       1
# 2              3       NaN       3
# 3              4       NaN       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 890          887       0.0       2
# 891          888       1.0       1
# 892          889       0.0       3
# 893          890       1.0       1
# 894          891       0.0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female   NaN      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.duplicated().sum()
# Out:
# 4

# %%
df.loc[df.duplicated(),:]
# Out:
#     PassengerId  Survived  Pclass                      Name   Sex   Age  \
# 43            5       0.0       3  Allen, Mr. William Henry  male  35.0
# 44            5       0.0       3  Allen, Mr. William Henry  male  35.0
# 45           43       0.0       3       Kraeff, Mr. Theodor  male   NaN
# 52           49       0.0       3       Samaan, Mr. Youssef  male   NaN
#
#     SibSp  Parch  Ticket     Fare Cabin Embarked
# 43      0      0  373450   8.0500   NaN        S
# 44      0      0  373450   8.0500   NaN        S
# 45      0      0  349253      NaN   NaN        C
# 52      2      0    2662  21.6792   NaN        C

# %%
df.drop_duplicates()
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1       0.0       3
# 1              2       NaN       1
# 2              3       NaN       3
# 3              4       NaN       1
# 4              5       0.0       3
# ..           ...       ...     ...
# 890          887       0.0       2
# 891          888       1.0       1
# 892          889       0.0       3
# 893          890       1.0       1
# 894          891       0.0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female   NaN      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...
